# %% [markdown]
# # Atividade 1
# ---
# Faça  na linguagem Python uma função que calcula as raízes da equação de segundo grau.
# Serão passados os coeficientes a, b e c. Caso a = 0, resolva com uma equação do primeiro grau, e se b = 0 gere uma exceção.

# %% [markdown]
# ## Importando uma biblioteca
# Código usado para importar uma biblioteca específica em python

# %%
from math import sqrt

# %% [markdown]
# ## Criando uma função
# Criando função que descobre raízes de equações quadráticas.

# %%
def zeros(a, b, c):

    if a == 0:
        if b == 0:
            raise ValueError("A Equação não é de segundo grau")
        else:
            return [-c/b]

    

    delta = b**2+(-4)*a*c  

    if delta < 0:
        return None
    elif delta == 0:
        x = (-b)/2*a
        return [x,x]
    else:
        x1 = (-b+sqrt(delta))/2*a
        x2 = (-b-sqrt(delta))/2*a
        return [x1,x2]

# %% [markdown]
# ## Executando o código
# Criando a função principal

# %%
def main():
    x = zeros(1, -5, 6)
    print(x)

if __name__  == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       3     print(x)
#       5 if __name__  == "__main__":
# ----> 6     main()
#
# Cell In[8], line 2, in main()
#       1 def main():
# ----> 2     x = zeros(0, 0, 6)
#       3     print(x)
#
# Cell In[3], line 5, in zeros(a, b, c)
#       3 if a == 0:
#       4     if b == 0:
# ----> 5         raise ValueError("A Equação não é de segundo grau")
#       6     else:
#       7         return [-c/b]
#
# ValueError: A Equação não é de segundo grau
